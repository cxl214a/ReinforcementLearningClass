# %%
import re
import pandas as pd
from pandas import Index

# %%
def process(file):
    kl = re.compile("kl:")
    templist= [text.split(",") for text in filter(lambda text: kl.search(text),file)]
    result = pd.DataFrame(
        [list(map(lambda text:string_pattern.sub("",text.replace("\n","")), each_tuple)) 
         for each_tuple in templist])
#     batch = re.compile("batch i:([0-9]+)") 
#     elasped = re.compile("Time elapsed: ([0-9]+) seconds")
#     result['batch'] = [ batch.findall(text)[0] for text in filter(lambda text: batch.findall(text), file)]
#     result['elapsed']=[ elasped.findall(text)[0] for text in filter(lambda text: elasped.findall(text), file)]
    result.columns= Index(["kl","lr_multiplier",'loss','entropy','explained_var_old','explained_var_new'])
    return result

# %%
with open("../log/gomoku/fourlayer/output8by8_old.txt",'r') as f:
    oldfile =f.readlines()

# %%
with open("../log/gomoku/fourlayer/output8by8_new.txt",'r') as f:
    newfile = f.readlines()
start = process(oldfile)
end   = process(newfile)[5:]
fourlayer=start.append(end,ignore_index=True)
fourlayer =fourlayer.astype("float32")
# fourlayer.plot(y=["entropy",'loss','explained_var_old','explained_var_new'], title= "4-layer")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-495f1b8b809a> in <module>()
#       1 with open("../log/gomoku/fourlayer/output8by8_new.txt",'r') as f:
#       2     newfile = f.readlines()
# ----> 3 start = process(oldfile)
#       4 end   = process(newfile)[5:]
#       5 fourlayer=start.append(end,ignore_index=True)
#
# <ipython-input-2-25cd1364153f> in process(file)
#       4     result = pd.DataFrame(
#       5         [list(map(lambda text:string_pattern.sub("",text.replace("\n","")), each_tuple))
# ----> 6          for each_tuple in templist])
#       7 #     batch = re.compile("batch i:([0-9]+)")
#       8 #     elasped = re.compile("Time elapsed: ([0-9]+) seconds")
#
# <ipython-input-2-25cd1364153f> in <listcomp>(.0)
#       4     result = pd.DataFrame(
#       5         [list(map(lambda text:string_pattern.sub("",text.replace("\n","")), each_tuple))
# ----> 6          for each_tuple in templist])
#       7 #     batch = re.compile("batch i:([0-9]+)")
#       8 #     elasped = re.compile("Time elapsed: ([0-9]+) seconds")
#
# <ipython-input-2-25cd1364153f> in <lambda>(text)
#       3     templist= [text.split(",") for text in filter(lambda text: kl.search(text),file)]
#       4     result = pd.DataFrame(
# ----> 5         [list(map(lambda text:string_pattern.sub("",text.replace("\n","")), each_tuple))
#       6          for each_tuple in templist])
#       7 #     batch = re.compile("batch i:([0-9]+)")
#
# NameError: name 'string_pattern' is not defined

# %%
with open("./log/threelayer/output8by8_simple_old.txt",'r') as f:
    oldfile =f.readlines()
with open("./log/threelayer/output8by8_simple_new.txt",'r') as f:
    newfile = f.readlines()
start = process(oldfile)
end   = process(newfile)[5:]
threelayer =start.append(end,ignore_index=True)
threelayer = threelayer.astype("float32")
threelayer.plot(y=["entropy",'loss','explained_var_old','explained_var_new'], title= "3-layer")

# %%
with open("./log/fivelayer/output8by8_5layers.txt") as f:
    file = f.readlines()

fivelayer = process(file)
# start
fivelayer = fivelayer.astype("float32")
# fivelayer.plot(y=["entropy",'loss','explained_var_old','explained_var_new'], title= "3-layer")

# %%
loss = pd.DataFrame()
loss['4-channel'] = fourlayer.loss[0:800]
loss['5-channel'] = fivelayer.loss[0:800]
loss['3-channel'] = threelayer.loss[0:800]

# %%
loss.plot(y= ['3-channel','4-channel','5-channel'],title = "loss")

# %%
entropy = pd.DataFrame()
entropy['4-channel'] = fourlayer.entropy[0:800]
entropy['5-channel'] = fivelayer.entropy[0:800]
entropy['3-channel'] = threelayer.entropy[0:800]

# %%
entropy.plot(y= ['3-channel','4-channel','5-channel'],title = "entropy")
